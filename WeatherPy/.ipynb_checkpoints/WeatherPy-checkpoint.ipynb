# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv

# Import API keys
import json
config = json.load(open("../config.json"))

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
params = {
    "appid": config["weather_api_key"],
    'units': 'imperial',
}

# Variables
lat = []
lng = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
record = 0
record_set = 1

print("Beginning Data Retrieval\n-----------------------------")

for city in cities:
    params.update({
        'q': city,
    })
    response = requests.get(url, params).json()
    record += 1
    if record > 49:
        record = 1
        record_set += 1
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        print(f"Processing Record {record} of Set {record_set} | {city}")
    except KeyError:
        lat.append(np.nan)
        lng.append(np.nan)
        max_temp.append(np.nan)
        humidity.append(np.nan)
        cloudiness.append(np.nan)
        wind_speed.append(np.nan)
        country.append(np.nan)
        date.append(np.nan)
        print('City not found. Skipping...')
    
print("-----------------------------\nData Retrieval Complete\n-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | newport
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | dickinson
# Processing Record 11 of Set 1 | hami
# Processing Record 12 of Set 1 | bethel
# Processing Record 13 of Set 1 | luderitz
# Processing Record 14 of Set 1 | provideniya
# City not found. Skipping...
# Processing Record 16 of Set 1 | cabo san lucas
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | gudibanda
# Processing Record 20 of Set 1 | victoria
# Processing Record 21 of Set 1 | broome
# City not found. Skipping...
# Processing Record 23 of Set 1 | sao desiderio
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | omsukchan
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | sao joao da barra
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | fortuna
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | houston
# Processing Record 32 of Set 1 | bengkulu
# Processing Record 33 of Set 1 | ciudad bolivar
# Processing Record 34 of Set 1 | jiazi
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | yumen
# Processing Record 38 of Set 1 | mayo
# Processing Record 39 of Set 1 | hofn
# Processing Record 40 of Set 1 | tessalit
# Processing Record 41 of Set 1 | anadyr
# Processing Record 42 of Set 1 | katherine
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | salym
# Processing Record 45 of Set 1 | basco
# Processing Record 46 of Set 1 | mgandu
# Processing Record 47 of Set 1 | genhe
# Processing Record 48 of Set 1 | norman wells
# Processing Record 49 of Set 1 | aninoasa
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | jamestown
# Processing Record 3 of Set 2 | srednekolymsk
# Processing Record 4 of Set 2 | dabakala
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | cidreira
# Processing Record 7 of Set 2 | voh
# Processing Record 8 of Set 2 | mount gambier
# Processing Record 9 of Set 2 | alofi
# Processing Record 10 of Set 2 | flinders
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | port moresby
# Processing Record 13 of Set 2 | rocha
# Processing Record 14 of Set 2 | puerto baquerizo moreno
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | bluff
# Processing Record 17 of Set 2 | mahebourg
# City not found. Skipping...
# Processing Record 19 of Set 2 | gambela
# Processing Record 20 of Set 2 | abu samrah
# Processing Record 21 of Set 2 | wanning
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | ponta do sol
# Processing Record 25 of Set 2 | hualmay
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | olinda
# Processing Record 29 of Set 2 | hithadhoo
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | hambantota
# Processing Record 32 of Set 2 | binga
# Processing Record 33 of Set 2 | kapaa
# City not found. Skipping...
# Processing Record 35 of Set 2 | mataura
# Processing Record 36 of Set 2 | kalga
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | taoudenni
# Processing Record 39 of Set 2 | santa barbara
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | waitati
# Processing Record 42 of Set 2 | riyadh
# Processing Record 43 of Set 2 | tougan
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | sept-iles
# Processing Record 46 of Set 2 | shingu
# Processing Record 47 of Set 2 | nakhon si thammarat
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | port alfred
# Processing Record 1 of Set 3 | carutapera
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | pisco
# Processing Record 4 of Set 3 | narsaq
# Processing Record 5 of Set 3 | bafra
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | richards bay
# Processing Record 9 of Set 3 | koumac
# Processing Record 10 of Set 3 | fort madison
# Processing Record 11 of Set 3 | mar del plata
# Processing Record 12 of Set 3 | pingliang
# Processing Record 13 of Set 3 | hasaki
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | palana
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | kodiak
# Processing Record 18 of Set 3 | san anselmo
# Processing Record 19 of Set 3 | ambon
# Processing Record 20 of Set 3 | roald
# Processing Record 21 of Set 3 | tual
# City not found. Skipping...
# Processing Record 23 of Set 3 | castro
# Processing Record 24 of Set 3 | baghmara
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | altay
# Processing Record 27 of Set 3 | gornopravdinsk
# Processing Record 28 of Set 3 | eyl
# Processing Record 29 of Set 3 | muisne
# Processing Record 30 of Set 3 | san cristobal
# Processing Record 31 of Set 3 | edd
# Processing Record 32 of Set 3 | nome
# City not found. Skipping...
# Processing Record 34 of Set 3 | golovchino
# Processing Record 35 of Set 3 | dutlwe
# Processing Record 36 of Set 3 | camacha
# Processing Record 37 of Set 3 | birao
# Processing Record 38 of Set 3 | margate
# Processing Record 39 of Set 3 | hollins
# Processing Record 40 of Set 3 | abong mbang
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | flic en flac
# Processing Record 43 of Set 3 | sola
# Processing Record 44 of Set 3 | correntina
# Processing Record 45 of Set 3 | college
# Processing Record 46 of Set 3 | galle
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 3 | faya
# Processing Record 1 of Set 4 | bredasdorp
# Processing Record 2 of Set 4 | the valley
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | taltal
# Processing Record 7 of Set 4 | biskupiec
# Processing Record 8 of Set 4 | fare
# City not found. Skipping...
# Processing Record 10 of Set 4 | katsuura
# Processing Record 11 of Set 4 | srivardhan
# Processing Record 12 of Set 4 | te anau
# Processing Record 13 of Set 4 | angol
# City not found. Skipping...
# Processing Record 15 of Set 4 | pitimbu
# Processing Record 16 of Set 4 | araouane
# Processing Record 17 of Set 4 | shaunavon
# Processing Record 18 of Set 4 | simao
# City not found. Skipping...
# Processing Record 20 of Set 4 | sisimiut
# Processing Record 21 of Set 4 | atuona
# Processing Record 22 of Set 4 | carnarvon
# City not found. Skipping...
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | vao
# Processing Record 26 of Set 4 | umm lajj
# Processing Record 27 of Set 4 | bilma
# Processing Record 28 of Set 4 | diego de almagro
# City not found. Skipping...
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | binzhou
# Processing Record 32 of Set 4 | okhotsk
# Processing Record 33 of Set 4 | ilinskiy
# Processing Record 34 of Set 4 | nouakchott
# Processing Record 35 of Set 4 | aklavik
# Processing Record 36 of Set 4 | hobyo
# Processing Record 37 of Set 4 | brigantine
# Processing Record 38 of Set 4 | athabasca
# Processing Record 39 of Set 4 | constitucion
# Processing Record 40 of Set 4 | diu
# Processing Record 41 of Set 4 | arrifes
# Processing Record 42 of Set 4 | haines junction
# Processing Record 43 of Set 4 | wilmington
# Processing Record 44 of Set 4 | malumfashi
# Processing Record 45 of Set 4 | port shepstone
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | bokoro
# Processing Record 48 of Set 4 | lavrentiya
# Processing Record 49 of Set 4 | tuatapere
# City not found. Skipping...
# Processing Record 2 of Set 5 | ndele
# Processing Record 3 of Set 5 | alice springs
# Processing Record 4 of Set 5 | tambopata
# Processing Record 5 of Set 5 | kapit
# Processing Record 6 of Set 5 | bajil
# Processing Record 7 of Set 5 | chor
# Processing Record 8 of Set 5 | khatanga
# Processing Record 9 of Set 5 | ahipara
# Processing Record 10 of Set 5 | kulhudhuffushi
# Processing Record 11 of Set 5 | grand-lahou
# Processing Record 12 of Set 5 | westport
# Processing Record 13 of Set 5 | inta
# Processing Record 14 of Set 5 | lagoa
# Processing Record 15 of Set 5 | kupang
# Processing Record 16 of Set 5 | langsa
# City not found. Skipping...
# Processing Record 18 of Set 5 | parang
# City not found. Skipping...
# Processing Record 20 of Set 5 | kenai
# Processing Record 21 of Set 5 | nikolskoye
# Processing Record 22 of Set 5 | awbari
# Processing Record 23 of Set 5 | san rafael
# City not found. Skipping...
# Processing Record 25 of Set 5 | moroni
# Processing Record 26 of Set 5 | poum
# Processing Record 27 of Set 5 | ryotsu
# Processing Record 28 of Set 5 | kirakira
# Processing Record 29 of Set 5 | faanui
# Processing Record 30 of Set 5 | zhob
# Processing Record 31 of Set 5 | nhulunbuy
# Processing Record 32 of Set 5 | webb city
# Processing Record 33 of Set 5 | whangarei
# Processing Record 34 of Set 5 | walvis bay
# Processing Record 35 of Set 5 | deniliquin
# Processing Record 36 of Set 5 | dingle
# Processing Record 37 of Set 5 | oistins
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | saint-leu
# Processing Record 40 of Set 5 | upernavik
# Processing Record 41 of Set 5 | pangnirtung
# Processing Record 42 of Set 5 | manaure
# Processing Record 43 of Set 5 | kelo
# Processing Record 44 of Set 5 | okmulgee
# Processing Record 45 of Set 5 | bandarbeyla
# Processing Record 46 of Set 5 | tsogni
# Processing Record 47 of Set 5 | bakel
# Processing Record 48 of Set 5 | cayenne
# City not found. Skipping...
# Processing Record 1 of Set 6 | hirara
# Processing Record 2 of Set 6 | port-gentil
# Processing Record 3 of Set 6 | huntingdon
# Processing Record 4 of Set 6 | baykit
# Processing Record 5 of Set 6 | avera
# Processing Record 6 of Set 6 | rosario
# Processing Record 7 of Set 6 | esperance
# Processing Record 8 of Set 6 | chemal
# Processing Record 9 of Set 6 | airai
# City not found. Skipping...
# Processing Record 11 of Set 6 | chapais
# Processing Record 12 of Set 6 | klaksvik
# Processing Record 13 of Set 6 | makat
# Processing Record 14 of Set 6 | muroto
# Processing Record 15 of Set 6 | clyde
# Processing Record 16 of Set 6 | lahaina
# Processing Record 17 of Set 6 | khuzhir
# Processing Record 18 of Set 6 | itarema
# Processing Record 19 of Set 6 | rovaniemi
# City not found. Skipping...
# Processing Record 21 of Set 6 | sao benedito do rio preto
# Processing Record 22 of Set 6 | manta
# Processing Record 23 of Set 6 | egvekinot
# Processing Record 24 of Set 6 | trzebnica
# Processing Record 25 of Set 6 | praia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 6 | kagoro
# Processing Record 29 of Set 6 | chicama
# Processing Record 30 of Set 6 | aksarka
# City not found. Skipping...
# Processing Record 32 of Set 6 | ponta delgada
# Processing Record 33 of Set 6 | aswan
# Processing Record 34 of Set 6 | beyneu
# Processing Record 35 of Set 6 | bathsheba
# Processing Record 36 of Set 6 | conakry
# Processing Record 37 of Set 6 | buala
# Processing Record 38 of Set 6 | kolyvan
# Processing Record 39 of Set 6 | kaitangata
# Processing Record 40 of Set 6 | bima
# Processing Record 41 of Set 6 | kalianget
# Processing Record 42 of Set 6 | atar
# Processing Record 43 of Set 6 | saint-augustin
# Processing Record 44 of Set 6 | qaqortoq
# Processing Record 45 of Set 6 | maturin
# Processing Record 46 of Set 6 | songjianghe
# Processing Record 47 of Set 6 | port elizabeth
# Processing Record 48 of Set 6 | fereydun kenar
# Processing Record 49 of Set 6 | miri
# Processing Record 1 of Set 7 | adrar
# Processing Record 2 of Set 7 | leshukonskoye
# Processing Record 3 of Set 7 | ballitoville
# Processing Record 4 of Set 7 | hervey bay
# Processing Record 5 of Set 7 | isiro
# Processing Record 6 of Set 7 | camopi
# Processing Record 7 of Set 7 | mongo
# Processing Record 8 of Set 7 | arlit
# Processing Record 9 of Set 7 | chokurdakh
# City not found. Skipping...
# Processing Record 11 of Set 7 | alta floresta
# Processing Record 12 of Set 7 | ixtapa
# Processing Record 13 of Set 7 | innisfail
# Processing Record 14 of Set 7 | mattoon
# Processing Record 15 of Set 7 | verkhnyaya inta
# Processing Record 16 of Set 7 | inhambane
# City not found. Skipping...
# Processing Record 18 of Set 7 | perivolion
# Processing Record 19 of Set 7 | port macquarie
# Processing Record 20 of Set 7 | minab
# Processing Record 21 of Set 7 | kastamonu
# City not found. Skipping...
# Processing Record 23 of Set 7 | roma
# Processing Record 24 of Set 7 | ancud
# City not found. Skipping...
# Processing Record 26 of Set 7 | dudinka
# Processing Record 27 of Set 7 | talnakh
# Processing Record 28 of Set 7 | meulaboh
# City not found. Skipping...
# Processing Record 30 of Set 7 | saint george
# Processing Record 31 of Set 7 | niquelandia
# Processing Record 32 of Set 7 | grindavik
# Processing Record 33 of Set 7 | bayan
# Processing Record 34 of Set 7 | ati
# Processing Record 35 of Set 7 | manzanillo
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | quesnel
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | port lincoln
# Processing Record 40 of Set 7 | shakhtinsk
# Processing Record 41 of Set 7 | nyrob
# Processing Record 42 of Set 7 | komsomolskiy
# Processing Record 43 of Set 7 | lucapa
# Processing Record 44 of Set 7 | isangel
# Processing Record 45 of Set 7 | monroe
# Processing Record 46 of Set 7 | vangaindrano
# Processing Record 47 of Set 7 | comodoro rivadavia
# Processing Record 48 of Set 7 | debno
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 1 of Set 8 | maldonado
# Processing Record 2 of Set 8 | solnechnyy
# Processing Record 3 of Set 8 | lata
# Processing Record 4 of Set 8 | nyimba
# Processing Record 5 of Set 8 | henties bay
# City not found. Skipping...
# Processing Record 7 of Set 8 | rio grande
# City not found. Skipping...
# Processing Record 9 of Set 8 | monteiro
# Processing Record 10 of Set 8 | toora-khem
# Processing Record 11 of Set 8 | agnibilekrou
# Processing Record 12 of Set 8 | rawson
# Processing Record 13 of Set 8 | cabedelo
# City not found. Skipping...
# Processing Record 15 of Set 8 | requena
# Processing Record 16 of Set 8 | opuwo
# Processing Record 17 of Set 8 | simpang
# Processing Record 18 of Set 8 | jiaocheng
# Processing Record 19 of Set 8 | anloga
# Processing Record 20 of Set 8 | kalmunai
# Processing Record 21 of Set 8 | azul
# Processing Record 22 of Set 8 | smithers
# Processing Record 23 of Set 8 | yerofey pavlovich
# Processing Record 24 of Set 8 | barcelos
# Processing Record 25 of Set 8 | alugan
# Processing Record 26 of Set 8 | oranjestad
# Processing Record 27 of Set 8 | inirida
# Processing Record 28 of Set 8 | qasigiannguit
# Processing Record 29 of Set 8 | clyde river
# Processing Record 30 of Set 8 | aasiaat
# Processing Record 31 of Set 8 | bilibino
# City not found. Skipping...
# Processing Record 33 of Set 8 | jambi
# Processing Record 34 of Set 8 | saint anthony
# Processing Record 35 of Set 8 | baoro
# Processing Record 36 of Set 8 | kahului
# Processing Record 37 of Set 8 | nizwa
# Processing Record 38 of Set 8 | viru
# Processing Record 39 of Set 8 | dunedin
# Processing Record 40 of Set 8 | lander
# Processing Record 41 of Set 8 | yeppoon
# Processing Record 42 of Set 8 | brigham city
# City not found. Skipping...
# Processing Record 44 of Set 8 | aksu
# Processing Record 45 of Set 8 | matagami
# Processing Record 46 of Set 8 | prince albert
# Processing Record 47 of Set 8 | luganville
# Processing Record 48 of Set 8 | zhigansk
# Processing Record 49 of Set 8 | ugoofaaru
# City not found. Skipping...
# Processing Record 2 of Set 9 | gubkinskiy
# City not found. Skipping...
# Processing Record 4 of Set 9 | kuryk
# Processing Record 5 of Set 9 | longyearbyen
# Processing Record 6 of Set 9 | codrington
# Processing Record 7 of Set 9 | koslan
# Processing Record 8 of Set 9 | asyut
# Processing Record 9 of Set 9 | phan thiet
# Processing Record 10 of Set 9 | bulgan
# Processing Record 11 of Set 9 | yenagoa
# Processing Record 12 of Set 9 | kimbe
# Processing Record 13 of Set 9 | fort nelson
# Processing Record 14 of Set 9 | hammerfest
# Processing Record 15 of Set 9 | eureka
# Processing Record 16 of Set 9 | tiksi
# Processing Record 17 of Set 9 | laguna
# Processing Record 18 of Set 9 | winneba
# Processing Record 19 of Set 9 | quatre cocos
# Processing Record 20 of Set 9 | krasnoselkup
# City not found. Skipping...
# Processing Record 22 of Set 9 | sioux lookout
# Processing Record 23 of Set 9 | shenjiamen
# City not found. Skipping...
# Processing Record 25 of Set 9 | whyalla
# Processing Record 26 of Set 9 | pokhara
# Processing Record 27 of Set 9 | batemans bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 9 | herat
# Processing Record 31 of Set 9 | guaruja
# Processing Record 32 of Set 9 | santo estevao
# Processing Record 33 of Set 9 | ranau
# Processing Record 34 of Set 9 | iracoubo
# Processing Record 35 of Set 9 | abu zabad
# City not found. Skipping...
# Processing Record 37 of Set 9 | maunabo
# Processing Record 38 of Set 9 | ribeira grande
# Processing Record 39 of Set 9 | bestobe
# Processing Record 40 of Set 9 | bayburt
# Processing Record 41 of Set 9 | tabas
# Processing Record 42 of Set 9 | tocopilla
# Processing Record 43 of Set 9 | jalu
# Processing Record 44 of Set 9 | micheweni
# Processing Record 45 of Set 9 | cururupu
# Processing Record 46 of Set 9 | tapes
# Processing Record 47 of Set 9 | xai-xai
# City not found. Skipping...
# Processing Record 49 of Set 9 | aktas
# Processing Record 1 of Set 10 | buzdyak
# Processing Record 2 of Set 10 | svetlogorsk
# Processing Record 3 of Set 10 | graaff-reinet
# Processing Record 4 of Set 10 | yar-sale
# Processing Record 5 of Set 10 | kuching
# Processing Record 6 of Set 10 | zlobin
# City not found. Skipping...
# Processing Record 8 of Set 10 | valdivia
# Processing Record 9 of Set 10 | quelimane
# Processing Record 10 of Set 10 | ambilobe
# Processing Record 11 of Set 10 | wuhu
# City not found. Skipping...
# Processing Record 13 of Set 10 | gat
# Processing Record 14 of Set 10 | midwest city
# Processing Record 15 of Set 10 | priiskovyy
# Processing Record 16 of Set 10 | washington
# Processing Record 17 of Set 10 | mananjary
# Processing Record 18 of Set 10 | dukat
# Processing Record 19 of Set 10 | kralendijk
# Processing Record 20 of Set 10 | san lorenzo
# Processing Record 21 of Set 10 | zharkent
# Processing Record 22 of Set 10 | sao raimundo nonato
# Processing Record 23 of Set 10 | marsh harbour
# Processing Record 24 of Set 10 | valparaiso
# City not found. Skipping...
# Processing Record 26 of Set 10 | atbasar
# Processing Record 27 of Set 10 | urumqi
# Processing Record 28 of Set 10 | jakar
# Processing Record 29 of Set 10 | naze
# Processing Record 30 of Set 10 | xiaoshi
# Processing Record 31 of Set 10 | bundaberg
# Processing Record 32 of Set 10 | teya
# City not found. Skipping...
# Processing Record 34 of Set 10 | paamiut
# Processing Record 35 of Set 10 | golovino
# City not found. Skipping...
# Processing Record 37 of Set 10 | beringovskiy
# Processing Record 38 of Set 10 | tabalosos
# Processing Record 39 of Set 10 | piacabucu
# Processing Record 40 of Set 10 | brae
# Processing Record 41 of Set 10 | muzhi
# Processing Record 42 of Set 10 | severo-kurilsk
# Processing Record 43 of Set 10 | brookhaven
# Processing Record 44 of Set 10 | ngunguru
# Processing Record 45 of Set 10 | mandalgovi
# Processing Record 46 of Set 10 | los llanos de aridane
# Processing Record 47 of Set 10 | yarkovo
# Processing Record 48 of Set 10 | klishkivtsi
# Processing Record 49 of Set 10 | kudahuvadhoo
# Processing Record 1 of Set 11 | sebring
# Processing Record 2 of Set 11 | algiers
# City not found. Skipping...
# Processing Record 4 of Set 11 | padang
# Processing Record 5 of Set 11 | terrace bay
# Processing Record 6 of Set 11 | vohibinany
# Processing Record 7 of Set 11 | koroni
# Processing Record 8 of Set 11 | acapulco
# Processing Record 9 of Set 11 | new kensington
# Processing Record 10 of Set 11 | razole
# Processing Record 11 of Set 11 | olafsvik
# Processing Record 12 of Set 11 | wagar
# Processing Record 13 of Set 11 | manokwari
# Processing Record 14 of Set 11 | litovko
# Processing Record 15 of Set 11 | bani walid
# Processing Record 16 of Set 11 | tura
# Processing Record 17 of Set 11 | kokopo
# Processing Record 18 of Set 11 | bugene
# Processing Record 19 of Set 11 | fairbanks
# Processing Record 20 of Set 11 | keflavik
# Processing Record 21 of Set 11 | kemin
# Processing Record 22 of Set 11 | rio gallegos
# Processing Record 23 of Set 11 | hefei
# Processing Record 24 of Set 11 | nara
# Processing Record 25 of Set 11 | galveston
# Processing Record 26 of Set 11 | osoyoos
# Processing Record 27 of Set 11 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 29 of Set 11 | pozo colorado
# Processing Record 30 of Set 11 | burns lake
# Processing Record 31 of Set 11 | malindi
# Processing Record 32 of Set 11 | aqtobe
# Processing Record 33 of Set 11 | iwanai
# Processing Record 34 of Set 11 | sosnovo-ozerskoye
# Processing Record 35 of Set 11 | uwajima
# Processing Record 36 of Set 11 | leningradskiy
# Processing Record 37 of Set 11 | neiafu
# Processing Record 38 of Set 11 | latung
# Processing Record 39 of Set 11 | bloemfontein
# Processing Record 40 of Set 11 | diamantino
# Processing Record 41 of Set 11 | kavieng
# Processing Record 42 of Set 11 | mugur-aksy
# Processing Record 43 of Set 11 | doha
# Processing Record 44 of Set 11 | yarmouth
# Processing Record 45 of Set 11 | coihaique
# Processing Record 46 of Set 11 | weligama
# Processing Record 47 of Set 11 | sinazongwe
# Processing Record 48 of Set 11 | tiarei
# City not found. Skipping...
# Processing Record 1 of Set 12 | sao miguel do araguaia
# Processing Record 2 of Set 12 | turukhansk
# Processing Record 3 of Set 12 | west wendover
# City not found. Skipping...
# Processing Record 5 of Set 12 | astoria
# Processing Record 6 of Set 12 | la ronge
# Processing Record 7 of Set 12 | daru
# Processing Record 8 of Set 12 | carauari
# Processing Record 9 of Set 12 | mozarlandia
# Processing Record 10 of Set 12 | igrim
# Processing Record 11 of Set 12 | dubbo
# Processing Record 12 of Set 12 | jumla
# City not found. Skipping...
# Processing Record 14 of Set 12 | tarauaca
# Processing Record 15 of Set 12 | tautira
# Processing Record 16 of Set 12 | hamada
# Processing Record 17 of Set 12 | touros
# City not found. Skipping...
# Processing Record 19 of Set 12 | hobbs
# City not found. Skipping...
# Processing Record 21 of Set 12 | kailua
# Processing Record 22 of Set 12 | fonte boa
# Processing Record 23 of Set 12 | kavaratti
# City not found. Skipping...
# Processing Record 25 of Set 12 | biak
# Processing Record 26 of Set 12 | green river
# Processing Record 27 of Set 12 | tavricheskoye
# Processing Record 28 of Set 12 | kolga
# Processing Record 29 of Set 12 | san roque
# Processing Record 30 of Set 12 | traverse city
# Processing Record 31 of Set 12 | husavik
# Processing Record 32 of Set 12 | salinopolis
# Processing Record 33 of Set 12 | deloraine
# Processing Record 34 of Set 12 | grand gaube
# Processing Record 35 of Set 12 | benatky nad jizerou
# Processing Record 36 of Set 12 | muros
# Processing Record 37 of Set 12 | marienburg
# Processing Record 38 of Set 12 | nagato
# City not found. Skipping...
# Processing Record 40 of Set 12 | kieta
# Processing Record 41 of Set 12 | iqaluit
# City not found. Skipping...
# Processing Record 43 of Set 12 | dwarka
# Processing Record 44 of Set 12 | havoysund
# Processing Record 45 of Set 12 | mikuni
# Processing Record 46 of Set 12 | shimoda
# Processing Record 47 of Set 12 | makakilo city
# Processing Record 48 of Set 12 | atasu
# Processing Record 49 of Set 12 | kasempa
# Processing Record 1 of Set 13 | kungurtug
# Processing Record 2 of Set 13 | mersing
# Processing Record 3 of Set 13 | amroha
# Processing Record 4 of Set 13 | lardos
# Processing Record 5 of Set 13 | porto velho
# Processing Record 6 of Set 13 | san policarpo
# Processing Record 7 of Set 13 | soure
# Processing Record 8 of Set 13 | darvari
# Processing Record 9 of Set 13 | jiuquan
# Processing Record 10 of Set 13 | lompoc
# Processing Record 11 of Set 13 | vila velha
# Processing Record 12 of Set 13 | kochubey
# Processing Record 13 of Set 13 | pontes e lacerda
# Processing Record 14 of Set 13 | safranbolu
# Processing Record 15 of Set 13 | port augusta
# Processing Record 16 of Set 13 | ostrovnoy
# Processing Record 17 of Set 13 | emerald
# Processing Record 18 of Set 13 | benguela
# Processing Record 19 of Set 13 | chaguanas
# Processing Record 20 of Set 13 | ampanihy
# Processing Record 21 of Set 13 | marystown
# Processing Record 22 of Set 13 | harrai
# Processing Record 23 of Set 13 | imbituba
# Processing Record 24 of Set 13 | nizhniy kuranakh
# Processing Record 25 of Set 13 | berbera
# Processing Record 26 of Set 13 | gazanjyk
# Processing Record 27 of Set 13 | saint-georges
# Processing Record 28 of Set 13 | mathbaria
# Processing Record 29 of Set 13 | ouadda
# Processing Record 30 of Set 13 | la palma
# Processing Record 31 of Set 13 | pizarro
# Processing Record 32 of Set 13 | tulun
# Processing Record 33 of Set 13 | road town
# Processing Record 34 of Set 13 | jiquilisco
# Processing Record 35 of Set 13 | san patricio
# Processing Record 36 of Set 13 | bikin
# Processing Record 37 of Set 13 | vardo
# Processing Record 38 of Set 13 | pemberton
# Processing Record 39 of Set 13 | lakhipur
# Processing Record 40 of Set 13 | konongo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Use CSV writer to write API output to an out_file
with open(output_data_file, 'w', newline='') as out_file:
    writer = csv.writer(out_file)
    writer.writerows(zip(cities, lat, lng, max_temp, humidity, cloudiness, wind_speed, country, date))

# %%
# Import data from the CSV out_file, add header names and change Date type to object to maintain UNIX timestamp string
csv_file = pd.read_csv(output_data_file, 
                       names='City Lat Lng Max_Temp Humidity Cloudiness Wind_Speed Country Date'.split(), 
                       dtype={"Date": object})
df = pd.DataFrame(csv_file)
# Drop np.nan values and reset index
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#              City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0         newport  51.5877   -2.9984     35.01      76.0        73.0
# 1    punta arenas -53.1500  -70.9167     69.80      28.0         0.0
# 2         rikitea -23.1203 -134.9692     77.63      72.0        90.0
# 3       ilulissat  69.2167  -51.1000     19.40      49.0         0.0
# 4       busselton -33.6500  115.3333     63.00      99.0        87.0
# ..            ...      ...       ...       ...       ...         ...
# 558         bikin  46.8161  134.2600    -17.63      87.0        59.0
# 559         vardo  70.3705   31.1107     21.20      79.0        90.0
# 560     pemberton  50.3164 -122.8027     32.00      86.0        90.0
# 561      lakhipur  26.0299   90.3041     57.88      49.0         0.0
# 562       konongo   6.6167   -1.2167     76.77      87.0        46.0
#
#      Wind_Speed Country        Date
# 0         23.73      GB  1612739420
# 1          6.91      CL  1612739622
# 2         13.13      PF  1612739622
# 3         24.16      GL  1612739485
# 4          1.99      AU  1612739623
# ..          ...     ...         ...
# 558        3.15      RU  1612739898
# 559       18.41      NO  1612739731
# 560        2.30      CA  1612739898
# 561        3.11      IN  1612739899
# 562        3.91      GH  1612739899
#
# [563 rows x 9 columns]

# %%
# Change Date dtype from object to int
df['Date'] = df['Date'].astype(int)

# Create a new column Date with custom format
df['Date_Custom'] = df['Date'].apply(lambda x: time.strftime("%b %d, %Y | %I:%M:%S %p", time.gmtime(x)))

# Rename Date column
df.rename(columns={
    'Date': 'Date_UNIX',
}, inplace = True)

# %%
df.head()
# Out:
#            City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0       newport  51.5877   -2.9984     35.01      76.0        73.0
# 1  punta arenas -53.1500  -70.9167     69.80      28.0         0.0
# 2       rikitea -23.1203 -134.9692     77.63      72.0        90.0
# 3     ilulissat  69.2167  -51.1000     19.40      49.0         0.0
# 4     busselton -33.6500  115.3333     63.00      99.0        87.0
#
#    Wind_Speed Country   Date_UNIX                 Date_Custom
# 0       23.73      GB  1612739420  Feb 07, 2021 | 11:10:20 PM
# 1        6.91      CL  1612739622  Feb 07, 2021 | 11:13:42 PM
# 2       13.13      PF  1612739622  Feb 07, 2021 | 11:13:42 PM
# 3       24.16      GL  1612739485  Feb 07, 2021 | 11:11:25 PM
# 4        1.99      AU  1612739623  Feb 07, 2021 | 11:13:43 PM

# %%
df.describe()
# Out:
#               Lat         Lng    Max_Temp    Humidity  Cloudiness  Wind_Speed  \
# count  563.000000  563.000000  563.000000  563.000000  563.000000  563.000000
# mean    18.494557   17.664143   50.281563   72.603908   52.110124    8.760053
# std     33.452003   92.244414   31.625835   19.307802   38.261815    6.168922
# min    -54.800000 -179.166700  -37.120000    6.000000    0.000000    0.130000
# 25%     -8.844250  -63.363200   28.510000   64.000000   15.000000    3.935000
# 50%     20.878300   24.662200   62.600000   77.000000   53.000000    7.850000
# 75%     46.991350   96.249250   76.335000   87.000000   90.000000   12.135000
# max     78.218600  179.316700   87.800000  100.000000  100.000000   40.290000
#
#           Date_UNIX
# count  5.630000e+02
# mean   1.612740e+09
# std    1.185931e+02
# min    1.612739e+09
# 25%    1.612740e+09
# 50%    1.612740e+09
# 75%    1.612740e+09
# max    1.612740e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Checking whether max is over 100%
df['Humidity'].max()
# Out:
# 100.0

# %%
# Checking top 5 largest humidity datasets
df.nlargest(5, 'Humidity')
# Out:
#            City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 57        vaini -21.2000 -175.2000     77.00     100.0        90.0
# 72   hambantota   6.1241   81.1185     75.20     100.0         0.0
# 151   carnarvon -24.8667  113.6333     77.00     100.0         8.0
# 190      kupang -10.1667  123.5833     75.20     100.0        20.0
# 228       airai  -8.9266  125.4092     63.54     100.0       100.0
#
#      Wind_Speed Country   Date_UNIX                 Date_Custom
# 57        10.36      TO  1612739648  Feb 07, 2021 | 11:14:08 PM
# 72         6.91      LK  1612739469  Feb 07, 2021 | 11:11:09 PM
# 151        8.05      AU  1612739694  Feb 07, 2021 | 11:14:54 PM
# 190        2.30      ID  1612739432  Feb 07, 2021 | 11:10:32 PM
# 228        2.28      TL  1612739734  Feb 07, 2021 | 11:15:34 PM

# %%
print('There are no cities with Humidity higher than 100%')
# Out:
# There are no cities with Humidity higher than 100%

# %%
df.describe()
# Out:
#               Lat         Lng    Max_Temp    Humidity  Cloudiness  Wind_Speed  \
# count  563.000000  563.000000  563.000000  563.000000  563.000000  563.000000
# mean    18.494557   17.664143   50.281563   72.603908   52.110124    8.760053
# std     33.452003   92.244414   31.625835   19.307802   38.261815    6.168922
# min    -54.800000 -179.166700  -37.120000    6.000000    0.000000    0.130000
# 25%     -8.844250  -63.363200   28.510000   64.000000   15.000000    3.935000
# 50%     20.878300   24.662200   62.600000   77.000000   53.000000    7.850000
# 75%     46.991350   96.249250   76.335000   87.000000   90.000000   12.135000
# max     78.218600  179.316700   87.800000  100.000000  100.000000   40.290000
#
#           Date_UNIX
# count  5.630000e+02
# mean   1.612740e+09
# std    1.185931e+02
# min    1.612739e+09
# 25%    1.612740e+09
# 50%    1.612740e+09
# 75%    1.612740e+09
# max    1.612740e+09

# %% [markdown]
# ### Below two steps are not applicable - there are no cities with humidity over 100%

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.style.use('seaborn-darkgrid')

plt.figure(figsize=(10, 4))

x_axis = df['Lat']
y_axis = df['Max_Temp']

plt.scatter(x_axis, y_axis, edgecolors="black")
plt.title('City Latitude vs. Max Temperature (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°F)')
plt.savefig("output_data/Latitude_vs_MaxTemperature_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Maximum Temperature (°F) (y axis).
#
# As can be seen, at higher altitudes the lower the temperature, especially after moving out of the Tropics range which is roughly at +/-23 latitude.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10, 4))

x_axis = df['Lat']
y_axis = df['Humidity']

plt.scatter(x_axis, y_axis, edgecolors="black")
plt.title('City Latitude vs. Humidity (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Humidty (%)')
plt.savefig("output_data/Latitude_vs_Humidity_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Humidity (%) (y axis).
#
# There appears to be no relation whatsoever between latitudes and humidity across cities; although, most cities range above 60% humidity.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(10, 4))

x_axis = df['Lat']
y_axis = df['Cloudiness']

plt.scatter(x_axis, y_axis, edgecolors="black")
plt.title('City Latitude vs. Cloudiness (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig("output_data/Latitude_vs_Cloudiness_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Cloudiness (%) (y axis).
#
# There appears to be no relation whatsoever between latitudes and cloudiness across cities.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(10, 4))

x_axis = df['Lat']
y_axis = df['Wind_Speed']

plt.scatter(x_axis, y_axis, edgecolors="black")
plt.title('City Latitude vs. Wind Speed (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig("output_data/Latitude_vs_WindSpeed_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Wind Speed (mph) (y axis).
#
# There appears to be no relation whatsoever between latitudes and wind speed across cities; however, it can be stated that most wind speeds are concentrated below 10 miles per hour across cities; regardless of the latitude.

# %% [markdown]
# ## Linear Regression

# %%
# Northern Hemisphere DataFrame
northern_df = df[(df['Lat'] >= 0)]
northern_df.head()
# Out:
#         City      Lat      Lng  Max_Temp  Humidity  Cloudiness  Wind_Speed  \
# 0    newport  51.5877  -2.9984     35.01      76.0        73.0       23.73
# 3  ilulissat  69.2167 -51.1000     19.40      49.0         0.0       24.16
# 6  dickinson  29.4608 -95.0513     60.01      67.0         1.0       12.66
# 7       hami  42.8000  93.4500     29.01      80.0        79.0        1.10
# 8     bethel  41.3712 -73.4140     28.40      86.0        40.0        3.44
#
#   Country   Date_UNIX                 Date_Custom
# 0      GB  1612739420  Feb 07, 2021 | 11:10:20 PM
# 3      GL  1612739485  Feb 07, 2021 | 11:11:25 PM
# 6      US  1612739625  Feb 07, 2021 | 11:13:45 PM
# 7      CN  1612739625  Feb 07, 2021 | 11:13:45 PM
# 8      US  1612739556  Feb 07, 2021 | 11:12:36 PM

# %%
# Southern Hemisphere DataFrame
southern_df = df[(df['Lat'] < 0)]
southern_df.head()
# Out:
#              City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 1    punta arenas -53.1500  -70.9167     69.80      28.0         0.0
# 2         rikitea -23.1203 -134.9692     77.63      72.0        90.0
# 4       busselton -33.6500  115.3333     63.00      99.0        87.0
# 5     new norfolk -42.7826  147.0587     60.01      70.0        60.0
# 16  sao desiderio -12.3633  -44.9733     68.70      93.0       100.0
#
#     Wind_Speed Country   Date_UNIX                 Date_Custom
# 1         6.91      CL  1612739622  Feb 07, 2021 | 11:13:42 PM
# 2        13.13      PF  1612739622  Feb 07, 2021 | 11:13:42 PM
# 4         1.99      AU  1612739623  Feb 07, 2021 | 11:13:43 PM
# 5         1.01      AU  1612739624  Feb 07, 2021 | 11:13:44 PM
# 16        2.51      BR  1612739630  Feb 07, 2021 | 11:13:50 PM

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Max_Temp']

# linear regression model
slope, intercept, r, p, se = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
lineq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"

# Chart
plt.figure(figsize=(10,4))
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')
plt.title('Northern Hemisphere - City Latitude vs. Max Temperature (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°F)')
plt.annotate(f"The line equation is: {lineq}", xy=(0.05,0.3), xycoords='axes fraction', color='red', fontsize=12)
plt.annotate(f"The r-squared value is: {round(r**2,2)}", xy=(0.05,0.25), xycoords='axes fraction', color='red', fontsize=12)
plt.savefig("output_data/NH_Latitude_vs_MaxTemperature_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Maximum Temperature (°F) (y axis) of the Northern Hemisphere.
#
# There is a strong inverse correlation between altitude and maximum temperature. At higher altitudes, the lower the temperature.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Max_Temp']

# linear regression model
slope, intercept, r, p, se = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
lineq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"

# Chart
plt.figure(figsize=(10,4))
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')
plt.title('Southern Hemisphere - City Latitude vs. Max Temperature (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°F)')
plt.annotate(f"The line equation is: {lineq}", xy=(0.05,0.9), xycoords='axes fraction', color='red', fontsize=12)
plt.annotate(f"The r-squared value is: {round(r**2,2)}", xy=(0.05,0.85), xycoords='axes fraction', color='red', fontsize=12)
plt.savefig("output_data/SH_Latitude_vs_MaxTemperature_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Maximum Temperature (°F) (y axis) of the Southern Hemisphere.
#
# Although not a strong correlation, we can infer that temperature decreases as latitude decreases - this makes sense considering temperature decreases as we move down from the Tropic of Capricorn.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Humidity']

# linear regression model
slope, intercept, r, p, se = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
lineq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"

# Chart
plt.figure(figsize=(10,4))
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')
plt.title('Northern Hemisphere - City Latitude vs. Humidty (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Humidty (%)')
plt.annotate(f"The line equation is: {lineq}", xy=(0.75,0.1), xycoords='axes fraction', color='red', fontsize=12)
plt.annotate(f"The r-squared value is: {round(r**2,2)}", xy=(0.75,0.05), xycoords='axes fraction', color='red', fontsize=12)
plt.savefig("output_data/NH_Latitude_vs_Humidity_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Humidity (%) (y axis) of the Northern Hemisphere.
#
# Based on above scatter plot and low r-squared value, we can infer that there is no strong correlation between latitude and humidity; however, as we move closer to the north pole it appears most of humidity in the cities range above 60%.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Humidity']

# linear regression model
slope, intercept, r, p, se = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
lineq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"

# Chart
plt.figure(figsize=(10,4))
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')
plt.title('Southern Hemisphere - City Latitude vs. Humidity (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.annotate(f"The line equation is: {lineq}", xy=(0.05,0.1), xycoords='axes fraction', color='red', fontsize=12)
plt.annotate(f"The r-squared value is: {round(r**2,2)}", xy=(0.05,0.05), xycoords='axes fraction', color='red', fontsize=12)
plt.savefig("output_data/SH_Latitude_vs_Humidity_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Humidity (%) (y axis) of the Southern Hemisphere.
#
# Based on above scatter plot and low r-squared value, we can infer that there is no correlation between latitude and humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Cloudiness']

# linear regression model
slope, intercept, r, p, se = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
lineq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"

# Chart
plt.figure(figsize=(10,4))
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')
plt.title('Northern Hemisphere - City Latitude vs. Cloudiness (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(f"The line equation is: {lineq}", xy=(0.9,0.1), xycoords='axes fraction', color='red', fontsize=12)
plt.annotate(f"The r-squared value is: {round(r**2,2)}", xy=(0.9,0.05), xycoords='axes fraction', color='red', fontsize=12)
plt.savefig("output_data/NH_Latitude_vs_Cloudiness_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Cloudiness (%) (y axis) of the Northern Hemisphere.
#
# Based on above scatter plot and low r-squared value, we can infer that there is no correlation between latitude and cloudiness.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Cloudiness']

# linear regression model
slope, intercept, r, p, se = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
lineq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"

# Chart
plt.figure(figsize=(10,4))
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')
plt.title('Southern Hemisphere - City Latitude vs. Cloudiness (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.annotate(f"The line equation is: {lineq}", xy=(0.05,0.8), xycoords='axes fraction', color='red', fontsize=12)
plt.annotate(f"The r-squared value is: {round(r**2,2)}", xy=(0.05,0.75), xycoords='axes fraction', color='red', fontsize=12)
plt.savefig("output_data/SH_Latitude_vs_Cloudiness_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Cloudiness (%) (y axis) of the Southern Hemisphere.
#
# Based on above scatter plot and low r-squared value, we can infer that there is no correlation between latitude and cloudiness.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_df['Lat']
y_values = northern_df['Wind_Speed']

# linear regression model
slope, intercept, r, p, se = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
lineq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"

# Chart
plt.figure(figsize=(10,4))
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')
plt.title('Northern Hemisphere - City Latitude vs. Wind Speed (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(f"The line equation is: {lineq}", xy=(0.05,0.9), xycoords='axes fraction', color='red', fontsize=12)
plt.annotate(f"The r-squared value is: {round(r**2,2)}", xy=(0.05,0.85), xycoords='axes fraction', color='red', fontsize=12)
plt.savefig("output_data/NH_Latitude_vs_WindSpeed_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Wind Speed (mph) (y axis) of the Northern Hemisphere.
#
# Based on above scatter plot and low r-squared value, we can infer that there is no correlation between latitude and wind speeds; however, we can state that most wind speeds are concentrated below 10 miles per hour across cities; regardless of the latitude.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_df['Lat']
y_values = southern_df['Wind_Speed']

# linear regression model
slope, intercept, r, p, se = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
lineq = f"y = {str(round(slope,2))}x + {str(round(intercept,2))}"

# Chart
plt.figure(figsize=(10,4))
plt.scatter(x_values, y_values, edgecolors='black')
plt.plot(x_values, regress_values, color='red')
plt.title('Southern Hemisphere - City Latitude vs. Wind Speed (February 7th, 2021)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.annotate(f"The line equation is: {lineq}", xy=(0.05,0.9), xycoords='axes fraction', color='red', fontsize=12)
plt.annotate(f"The r-squared value is: {round(r**2,2)}", xy=(0.05,0.85), xycoords='axes fraction', color='red', fontsize=12)
plt.savefig("output_data/SH_Latitude_vs_WindSpeed_210207.png")
plt.show()

# %% [markdown]
# Above chart shows the relation between City Latitude (x axis) and Wind Speed (mph) (y axis) of the Southern Hemisphere.
#
# Based on above scatter plot and low r-squared value, we can infer that there is no correlation between latitude and wind speeds; however, we can state that most wind speeds are concentrated below 10 miles per hour across cities; regardless of the latitude.

# %% [markdown]
# ### Observable trends based on data:
# * We can infer that there is correlation between altitude and maximum temperature. As we move out of the Tropic Zone +/- 23 latitude, the temperature drops. So at higher/lower altitudes, the lower the temperature respectively.
# * We can infer that there is no correlation between altitude and wind speeds; most wind speeds are below 10 mph regardless of the altitude.
# * We can infer that there is no correlation between altitude and cloudiness or humidity.
